# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Generate a large dataset with missing values
np.random.seed(42)
num_rows = 10000
data = {
    'Feature1': np.random.normal(0, 1, num_rows),
    'Feature2': np.random.choice([1, 2, 3, 4, np.nan], num_rows),
    'Feature3': np.random.choice(['A', 'B', 'C', np.nan], num_rows)
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Feature1  Feature2 Feature3
# 0     0.496714       2.0      nan
# 1    -0.138264       1.0        B
# 2     0.647689       NaN        A
# 3     1.523030       2.0      nan
# 4    -0.234153       1.0        B
# ...        ...       ...      ...
# 9995  1.301102       NaN      nan
# 9996 -1.998345       3.0        B
# 9997 -0.705317       NaN        B
# 9998  0.495766       4.0        B
# 9999  0.644388       2.0        C
#
# [10000 rows x 3 columns]

# %%
# Create a heatmap to visualize missing values
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title('NaN and `nan` Value Locations')
plt.show()

# %%
# Mean imputation
mean_imputed = df.copy()
mean_imputed['Feature2'].fillna(df['Feature2'].mean(), inplace=True)

# %%
# Median imputation
median_imputed = df.copy()
median_imputed['Feature2'].fillna(df['Feature2'].median(), inplace=True)

# %%
# Mode imputation
mode_imputed = df.copy()
mode_imputed['Feature3'].fillna(df['Feature3'].mode()[0], inplace=True)

# %%
print("Original DataFrame:")
df.head(10)
# Out:
# Original DataFrame:
#    Feature1  Feature2 Feature3
# 0  0.496714       2.0      nan
# 1 -0.138264       1.0        B
# 2  0.647689       NaN        A
# 3  1.523030       2.0      nan
# 4 -0.234153       1.0        B
# 5 -0.234137       NaN        C
# 6  1.579213       4.0        B
# 7  0.767435       2.0        C
# 8 -0.469474       4.0        A
# 9  0.542560       3.0        C

# %%
print("Mean-Imputed DataFrame:")
mean_imputed.head(10)
# Out:
# Mean-Imputed DataFrame:
#    Feature1  Feature2 Feature3
# 0  0.496714  2.000000      nan
# 1 -0.138264  1.000000        B
# 2  0.647689  2.506607        A
# 3  1.523030  2.000000      nan
# 4 -0.234153  1.000000        B
# 5 -0.234137  2.506607        C
# 6  1.579213  4.000000        B
# 7  0.767435  2.000000        C
# 8 -0.469474  4.000000        A
# 9  0.542560  3.000000        C

# %%
print("Median-Imputed DataFrame:")
median_imputed.head(10)
# Out:
# Median-Imputed DataFrame:
#    Feature1  Feature2 Feature3
# 0  0.496714       2.0      nan
# 1 -0.138264       1.0        B
# 2  0.647689       3.0        A
# 3  1.523030       2.0      nan
# 4 -0.234153       1.0        B
# 5 -0.234137       3.0        C
# 6  1.579213       4.0        B
# 7  0.767435       2.0        C
# 8 -0.469474       4.0        A
# 9  0.542560       3.0        C

# %%
print("Mode-Imputed DataFrame:")
mode_imputed.head(10)
# Out:
# Mode-Imputed DataFrame:
#    Feature1  Feature2 Feature3
# 0  0.496714       2.0      nan
# 1 -0.138264       1.0        B
# 2  0.647689       NaN        A
# 3  1.523030       2.0      nan
# 4 -0.234153       1.0        B
# 5 -0.234137       NaN        C
# 6  1.579213       4.0        B
# 7  0.767435       2.0        C
# 8 -0.469474       4.0        A
# 9  0.542560       3.0        C
