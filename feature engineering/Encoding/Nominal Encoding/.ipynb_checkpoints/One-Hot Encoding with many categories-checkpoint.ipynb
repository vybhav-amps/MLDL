# %%
import pandas as pd

# Sample data with a categorical variable
data = {'category': ["Harper", "Lucas", "Harper", "Carter", "Liam", "Olivia", "Ella", "Amelia",
                     "Mia", "Samuel", "Emily", "Caden", "Lucas", "Michael", "David", "Victoria",
                     "Jackson", "James", "Caden", "Caleb", "Oliver", "Jackson", "Ethan", "William",
                     "Ethan", "Zoey", "Evelyn", "Grayson", "Zoey", "Luna", "Joseph", "Zoey", 
                     "Isabella", "Zoey", "Harper", "Victoria", "Noah", "Logan", "Henry", "Harper",
                     "Benjamin", "Logan", "Madison", "Aiden", "Layla", "Sofia", "Matthew", "Henry",
                     "Charlotte", "Joseph", "Ella", "Avery", "Chloe", "Chloe", "Noah", "Ethan",
                     "Madison", "Lucas", "Elizabeth", "Madison", "Madison", "Elijah", "Mason",
                     "Oliver", "Amelia", "Joseph", "Avery", "Victoria", "Victoria", "Lucas", 
                     "Michael", "Victoria", "Scarlett", "Grayson", "Ella", "Grayson", "Olivia",
                     "Luna", "Matthew", "Emily", "Aiden", "Evelyn", "Ava", "Liam", "James", "Olivia",
                     "Emma", "Grace", "Benjamin", "Evelyn", "Lucas", "Henry", "Zoey", "Grace",
                     "Avery", "Logan", "Elizabeth", "Sophia", "Liam", "Evelyn", "Matthew", "Caleb",
                     "Alexander", "Layla", "Alexander", "Emily", "Michael", "Emily", "Samuel", "Liam",
                     "Amelia", "Ethan", "Elizabeth", "Madison", "Evelyn", "Charlotte", "Emily", "David",
                     "Ella", "Grace", "Olivia", "David", "Jackson", "Carter", "Sophia", "Lucas", "Charlotte",
                     "Michael", "Penelope", "Zoey", "Victoria", "Ella", "Grayson", "Matthew", "Samuel",
                     "Samuel", "Isabella", "Scarlett", "Lucas", "Sophia", "Ella", "Sophia", "Michael",
                     "Harper", "Lucas", "Victoria", "Ava", "Olivia", "Mason", "Emma", "Ella", "Michael",
                     "Ethan", "Jackson", "Ella", "Mason", "Logan", "Sofia", "Harper", "Henry", "Oliver",
                     "Carter", "Caleb", "Abigail", "Elizabeth", "David", "Grayson", "Michael", "Matthew",
                     "Daniel", "Noah", "Evelyn", "Evelyn", "Grace", "Olivia", "Ethan", "Avery", "Mason",
                     "Penelope", "Victoria", "Jackson", "Benjamin", "Isabella", "Charlotte", "Alexander",
                     "Harper", "Victoria", "Emily", "Aiden", "Mason", "Emily", "Evelyn", "Luna", "William",
                     "Charlotte", "Logan", "Liam", "Logan", "Ava", "Ava", "Logan", "Matthew", "Grace", "Emily",
                     "Caden", "Scarlett", "Matthew", "Noah", "Liam", "Harper", "Sofia", "David", "David",
                     "Lucas", "Samuel", "Logan", "Zoey", "Avery", "Matthew", "Sophia", "Evelyn", "Logan",
                     "Avery", "Jackson", "Grayson", "Aiden", "Luna", "Elizabeth", "Layla", "James", "Jackson",
                     "Zoey", "Ella", "Mia", "Matthew", "Caleb", "Ethan", "Luna", "Amelia", "Samuel", "Charlotte",
                     "Samuel", "Caden", "Grayson", "Scarlett", "Grace", "Abigail", "Aiden", "Scarlett", "Alexander",
                     "Ella", "Logan", "Grace", "David", "Mason", "Chloe", "Amelia", "Samuel", "Grace", "Elijah",
                     "Carter", "Zoey", "Olivia", "Liam", "Madison", "Harper", "Elizabeth", "Liam", "Elijah",
                     "Aiden", "Harper", "Emma", "Emily", "Henry", "Avery", "Victoria", "Amelia", "Mia", "Elizabeth",
                     "Oliver", "Emily", "Benjamin", "Caden", "William", "Caleb", "Liam", "Zoey", "Samuel", "Emma",
                     "Henry", "Charlotte", "Caleb", "Noah", "Noah", "Lucas", "Ava", "Luna", "Grayson", "Oliver",
                     "Mia", "Ella", "Noah", "Samuel", "Avery", "Elizabeth", "Layla", "Abigail", "Olivia", "Zoey",
                     "Ella", "Harper", "Charlotte", "Charlotte", "Penelope", "Liam", "Caleb", "Henry", "Ella", 
                     "Olivia", "William", "Charlotte", "Luna", "Ella", "Carter", "Mason", "Grace", "Elizabeth",
                     "Grayson", "Ella", "Joseph", "Lucas", "James", "Penelope", "Liam", "Emily", "Layla", "Avery",
                     "Caden", "Ethan", "Caleb", "Harper", "Mia", "Oliver", "Logan", "Charlotte", "Ethan", "Mia",
                     "Caleb", "Charlotte", "Matthew", "Amelia", "Sophia", "Ella", "Isabella", "Sofia", "Isabella",
                     "David", "Mason", "Amelia", "Charlotte", "Grayson", "Grace", "Layla", "Luna", "Scarlett", 
                     "Madison", "Amelia", "Joseph", "Joseph", "Chloe", "Elizabeth", "Evelyn", "Emily", "Carter",
                     "Amelia", "Chloe", "Sophia", "Elijah", "Charlotte", "Matthew", "Scarlett", "Lucas", "Victoria",
                     "Carter", "Jackson", "Carter", "Caleb", "Elizabeth", "Caleb", "Joseph", "Ella", "Lucas", "Luna",
                     "Michael", "Caleb", "William", "Samuel", "Caleb", "James", "Carter", "Liam", "Victoria", "Evelyn",
                     "Grayson", "Logan", "Evelyn", "Emma", "Mia", "William", "Evelyn", "Michael", "Caleb", "Ethan",
                     "Harper", "Elizabeth", "Charlotte", "Emily", "Liam", "Alexander", "Caleb", "Olivia", "Isabella",
                     "Noah", "Caleb", "Oliver", "Mason", "Aiden", "Amelia", "Scarlett", "Elizabeth", "Matthew", 
                     "Alexander", "Noah", "Sophia", "Penelope", "Luna", "David", "Grayson", "Madison", "Chloe", 
                     "Mia", "Lucas", "Chloe", "David", "Elizabeth", "Sofia", "Madison", "Zoey", "Elijah", "Ava",
                     "Joseph", "Michael", "Grayson", "David", "Oliver", "Henry", "Elijah", "Sophia", "Madison", 
                     "Mason", "Mason", "Elizabeth", "Samuel", "Sofia", "Daniel", "Luna", "Olivia", "Aiden", "David",
                     "Amelia", "Charlotte", "James", "Mason", "Alexander", "Evelyn", "Amelia", "David", "Scarlett",
                     "Samuel", "David", "Michael", "Ella", "Zoey", "Joseph", "Scarlett", "Luna", "Jackson", "David",
                     "William", "Sophia", "Scarlett", "Elijah", "Elijah", "Scarlett", "Charlotte", "Liam", "Emma", 
                     "Abigail", "Samuel", "Jackson", "William", "Madison", "Ella", "Joseph", "Aiden", "James",
                     "Joseph", "Elijah", "Daniel", "Isabella", "Avery", "Avery", "Layla", "Lucas", "Emily",
                     "Avery", "Ava", "Elijah", "Daniel", "Aiden", "Avery", "Isabella", "Ethan", "Ethan", 
                     "Abigail", "Chloe", "Olivia", "Alexander", "Caleb", "Madison", "Luna", "Layla", "Madison",
                     "Aiden", "Grayson", "Samuel", "Lucas", "Joseph", "Penelope", "Lucas", "Liam", "Carter",
                     "Avery", "Emma", "Aiden", "Sofia", "Mason", "Penelope", "Henry", "Caden", "Elizabeth", 
                     "Layla", "Charlotte", "William", "Carter", "Evelyn", "Caleb", "Madison", "Mason", "Emma",
                     "Noah", "Luna", "Liam", "David", "Madison", "Henry", "Luna", "Ella", "Harper", "Emily", 
                     "Isabella", "Charlotte", "Charlotte", "Ella", "Caleb", "Elijah", "Ella", "Daniel",
                     "Charlotte", "Oliver", "Victoria", "Caden", "Aiden", "William", "Chloe", "Evelyn", 
                     "Luna", "Madison", "Abigail", "Logan", "Grace", "Henry", "Ethan", "Ava", "Evelyn", 
                     "Logan", "Emily", "Grace", "Ava", "Ava", "Chloe", "Avery", "Ava", "Luna", "Grayson",
                     "Grayson", "Michael", "Elijah", "Liam", "Victoria", "Layla", "Elizabeth", "Oliver", 
                     "Grace", "Grayson", "Penelope", "Chloe", "Olivia", "Samuel", "Mason", "Harper", "Charlotte",
                     "Isabella", "Layla", "Ava", "Oliver", "Grayson", "Daniel", "James", "Sophia", "Chloe",
                     "Caleb", "Michael", "Caleb", "Abigail", "William", "Sophia", "Noah", "Michael", "Caleb",
                     "Madison", "Joseph", "Liam", "Jackson", "Ella", "James", "Sofia", "William", "Penelope",
                     "Michael", "Samuel", "Isabella", "Victoria", "James", "Olivia", "Aiden", "Alexander", 
                     "Harper", "Emma", "Grayson", "Isabella", "Evelyn", "Zoey", "Amelia", "Henry", "Caleb",
                     "Jackson", "Ava", "Henry", "Layla", "Joseph", "Scarlett", "Victoria", "Alexander", 
                     "Elizabeth", "Isabella", "Emma", "Ella", "Charlotte", "Penelope", "Madison", "James",
                     "Grayson", "Caleb", "Alexander", "Alexander", "Victoria", "Ava", "David", "Scarlett",
                     "Chloe", "Avery", "Zoey", "Carter", "Carter", "Evelyn", "Caleb", "Joseph", "Liam", "Daniel",
                     "Joseph", "Oliver", "Matthew", "Lucas", "Caden", "Luna", "Noah", "Oliver", "Ella", "James",
                     "Jackson", "Logan", "Abigail", "Layla", "Abigail", "William", "Oliver", "Lucas", "Caleb", 
                     "Logan", "Emily", "Penelope", "Evelyn", "Amelia", "Ella", "Samuel", "Avery", "Victoria", 
                     "Scarlett", "Grace", "Evelyn", "Zoey", "Oliver", "Oliver", "Oliver", "Grace", "Harper",
                     "Ethan", "Zoey", "Samuel", "Mia", "Olivia", "Amelia", "Jackson", "Lucas", "Sophia", "Emma",
                     "William", "Chloe", "Grace", "Elijah", "Mia", "Mia", "Liam", "Madison", "Alexander", 
                     "Penelope", "Chloe", "David", "Joseph", "Liam", "James", "Henry", "Henry", "Caleb", 
                     "Grayson", "Grayson", "Liam", "Avery", "Penelope", "Liam", "Ava", "Isabella", "Chloe", 
                     "Carter", "Scarlett", "Joseph", "Emily", "Victoria", "Noah", "Logan", "Matthew", "Caden", 
                     "Daniel", "Benjamin", "Olivia", "Victoria", "Penelope", "William", "Chloe", "Mason", "Ava",
                     "David", "Mia", "Matthew", "Victoria", "Logan", "Isabella", "Joseph", "Harper", "James", 
                     "Ava", "Mason", "Layla", "Zoey", "Sophia", "Matthew", "Abigail", "Jackson", "Alexander", 
                     "Caden", "Samuel", "Elijah", "Noah", "Benjamin", "Avery", "Oliver", "Penelope", "Joseph",
                     "Grace", "Caden", "Isabella", "Layla", "Olivia", "James", "James", "Emma", "William", 
                     "Aiden", "Elizabeth", "Avery", "Ava", "Luna", "Evelyn", "Grayson", "Penelope", "Caden",
                     "James", "Grayson", "David", "Evelyn", "Ethan", "Scarlett", "Logan", "Mason", "James", 
                     "Evelyn", "Aiden", "Mia", "Olivia", "Sophia", "Lucas", "Michael", "Lucas", "Charlotte", 
                     "Liam", "Oliver", "Layla", "Victoria", "David", "Scarlett", "Noah", "Oliver", "Grace", 
                     "Luna", "Avery", "Michael", "Samuel", "Chloe", "Luna", "David", "Evelyn", "Benjamin", 
                     "Zoey", "Ella", "Victoria", "James", "Daniel", "Samuel", "Noah", "Victoria", "Liam", 
                     "Jackson", "Samuel", "Emma", "Michael", "David", "Mia", "Harper", "Emily", "Elizabeth",
                     "Lucas", "Benjamin", "Grace", "Ella", "Samuel", "James", "Sofia", "Isabella", "Henry", 
                     "Victoria", "Daniel", "Evelyn", "Amelia", "Amelia", "Ethan", "Charlotte", "Sophia", 
                     "Evelyn", "Sophia", "Mia", "Olivia", "David", "Noah", "Charlotte", "Elizabeth", "Ethan",
                     "Liam", "Penelope", "Ella", "Carter", "Elijah", "Daniel", "Scarlett", "Caden", "Zoey", 
                     "Jackson", "Noah", "Chloe", "Olivia", "Chloe", "Amelia", "Evelyn", "Caleb", "Jackson", 
                     "Evelyn", "Emily", "Avery", "Mia", "Charlotte", "Daniel", "Isabella", "Noah", "Sophia", 
                     "Harper", "Mason", "Jackson", "Luna", "Ava", "Penelope", "Evelyn", "Aiden", "David", 
                     "Alexander", "Abigail", "Liam", "Mia", "James", "Jackson", "Zoey", "Zoey", "Ethan", 
                     "Sofia", "Grayson", "Logan", "Emma", "Olivia", "Layla", "Liam", "Emma", "Ava", 
                     "William", "David", "Ethan", "Sophia", "Penelope", "Ella", "Sophia", "Abigail", 
                     "Zoey", "Evelyn", "Sofia", "Chloe", "Logan", "Ethan", "Ella", "Avery", "Grayson",
                     "Benjamin", "James", "Michael", "Samuel", "Isabella", "Mason", "Caden", "Henry", 
                     "Joseph", "Mia", "Daniel", "Noah"]}
df = pd.DataFrame(data)

# %%
# Count the occurrences of each word in the 'town' column
word_counts = df['category'].value_counts()

# Display the word counts
print(word_counts)
# Out:
# Ella         31
# Evelyn       31
# Liam         28
# Caleb        28
# Charlotte    27
# Grayson      26
# David        26
# Victoria     25
# Samuel       25
# Avery        23
# Lucas        23
# Zoey         23
# Luna         22
# James        22
# Olivia       21
# Chloe        21
# Elizabeth    21
# Logan        21
# Joseph       21
# Jackson      20
# Noah         20
# Sophia       20
# Emily        20
# Mason        20
# Ethan        20
# Oliver       20
# Ava          20
# Harper       20
# Scarlett     19
# Grace        19
# Penelope     19
# Isabella     19
# Michael      19
# Amelia       19
# Madison      19
# Mia          18
# Henry        17
# William      17
# Layla        17
# Aiden        17
# Matthew      16
# Elijah       15
# Caden        15
# Emma         15
# Alexander    15
# Carter       15
# Daniel       13
# Abigail      12
# Sofia        11
# Benjamin      9
# Name: category, dtype: int64

# %%
# Get the top five most repeated words
top_ten_words = word_counts.head(5).index.tolist()

# Create a new DataFrame with one-hot encoding for the top ten words
one_hot_encoded = pd.get_dummies(df[df['category'].isin(top_ten_words)], columns=['category'])

# Display the one-hot encoded DataFrame
one_hot_encoded
# Out:
#      category_Caleb  category_Charlotte  category_Ella  category_Evelyn  \
# 4                 0                   0              0                0
# 6                 0                   0              1                0
# 19                1                   0              0                0
# 26                0                   0              0                1
# 48                0                   1              0                0
# ..              ...                 ...            ...              ...
# 955               0                   0              0                0
# 968               0                   0              0                0
# 976               0                   0              1                0
# 980               0                   0              0                1
# 985               0                   0              1                0
#
#      category_Liam
# 4                1
# 6                0
# 19               0
# 26               0
# ...
